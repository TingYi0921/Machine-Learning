# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data
# mpg 通常代表 "miles per gallon"，這是一個測量汽車燃油效率的指標，意指每加侖汽油可以行駛的英里數。
#
# 這個指標幫助消費者理解汽車在標準條件下的燃油經濟性。高的 mpg 值表示汽車更加節能，因為它可以在消耗較少的燃料的情況下行駛更長的距離。這是評估汽車性能的一個重要指標，尤其在考慮環保和經濟性時更是如此。 其他欄位如 cylinders（氣缸數）、 displacement（排氣量）
#
# 、horsepower（馬力）、weight（重量）、
#
# acceleration（加速度）、
#
# model_year（型號年份）、
#
# origin（產地）和
#
# name（車型名稱），

# %%
df = pd.read_csv("mpg.csv")
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
g = df.groupby("model_year")
g
list(g)
# Out:
# [(70,
#        mpg  cylinders  displacement horsepower  weight  acceleration  \
#   0   18.0          8         307.0        130    3504          12.0
#   1   15.0          8         350.0        165    3693          11.5
#   2   18.0          8         318.0        150    3436          11.0
#   3   16.0          8         304.0        150    3433          12.0
#   4   17.0          8         302.0        140    3449          10.5
#   5   15.0          8         429.0        198    4341          10.0
#   6   14.0          8         454.0        220    4354           9.0
#   7   14.0          8         440.0        215    4312           8.5
#   8   14.0          8         455.0        225    4425          10.0
#   9   15.0          8         390.0        190    3850           8.5
#   10  15.0          8         383.0        170    3563          10.0
#   11  14.0          8         340.0        160    3609           8.0
# ...

# %%
g = df.groupby("model_year")
meanG = g.mean(numeric_only=True)
meanG
# Out:
#                   mpg  cylinders  displacement       weight  acceleration  \
# model_year
# 70          17.689655   6.758621    281.413793  3372.793103     12.948276
# 71          21.250000   5.571429    209.750000  2995.428571     15.142857
# 72          18.714286   5.821429    218.375000  3237.714286     15.125000
# 73          17.100000   6.375000    256.875000  3419.025000     14.312500
# 74          22.703704   5.259259    171.740741  2877.925926     16.203704
# 75          20.266667   5.600000    205.533333  3176.800000     16.050000
# 76          21.573529   5.647059    197.794118  3078.735294     15.941176
# 77          23.375000   5.464286    191.392857  2997.357143     15.435714
# 78          24.061111   5.361111    177.805556  2861.805556     15.805556
# 79          25.093103   5.827586    206.689655  3055.344828     15.813793
# 80          33.696552   4.137931    115.827586  2436.655172     16.934483
# ...

# %%
meanG["mpg"]
# Out:
# model_year
# 70    17.689655
# 71    21.250000
# 72    18.714286
# 73    17.100000
# 74    22.703704
# 75    20.266667
# 76    21.573529
# 77    23.375000
# 78    24.061111
# 79    25.093103
# 80    33.696552
# 81    30.334483
# 82    31.709677
# Name: mpg, dtype: float64

# %%
meanG.describe()
# Out:
#              mpg  cylinders  displacement       weight  acceleration  \
# count  13.000000  13.000000     13.000000    13.000000     13.000000
# mean   23.659059   5.433688    192.106073  2960.466485     15.589128
# std     5.308042   0.761233     47.662157   325.173903      1.051988
# min    17.100000   4.137931    115.827586  2436.655172     12.948276
# 25%    20.266667   5.259259    171.740741  2861.805556     15.142857
# 50%    22.703704   5.571429    197.794118  2997.357143     15.813793
# 75%    25.093103   5.821429    209.750000  3176.800000     16.203704
# max    33.696552   6.758621    281.413793  3419.025000     16.934483
#
#           origin
# count  13.000000
# mean    1.579195
# std     0.260025
# min     1.275862
# 25%     1.428571
# 50%     1.535714
# 75%     1.645161
# max     2.206897

# %%
meanG.describe().T
# Out:
#               count         mean         std          min          25%  \
# mpg            13.0    23.659059    5.308042    17.100000    20.266667
# cylinders      13.0     5.433688    0.761233     4.137931     5.259259
# displacement   13.0   192.106073   47.662157   115.827586   171.740741
# weight         13.0  2960.466485  325.173903  2436.655172  2861.805556
# acceleration   13.0    15.589128    1.051988    12.948276    15.142857
# origin         13.0     1.579195    0.260025     1.275862     1.428571
#
#                       50%          75%          max
# mpg             22.703704    25.093103    33.696552
# cylinders        5.571429     5.821429     6.758621
# displacement   197.794118   209.750000   281.413793
# weight        2997.357143  3176.800000  3419.025000
# acceleration    15.813793    16.203704    16.934483
# origin           1.535714     1.645161     2.206897

# %% [markdown]
# ## Groupby Multiple Columns

# %%
mcgroup = df.groupby(["model_year","cylinders"])
print(list(mcgroup))
# Out:
# [((70, 4),      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 14  24.0          4         113.0         95    2372          15.0
# 18  27.0          4          97.0         88    2130          14.5
# 19  26.0          4          97.0         46    1835          20.5
# 20  25.0          4         110.0         87    2672          17.5
# 21  24.0          4         107.0         90    2430          14.5
# 22  25.0          4         104.0         95    2375          17.5
# 23  26.0          4         121.0        113    2234          12.5
#
#     model_year  origin                          name
# 14          70       3         toyota corona mark ii
# 18          70       3                  datsun pl510
# 19          70       2  volkswagen 1131 deluxe sedan
# 20          70       2                   peugeot 504
# 21          70       2                   audi 100 ls
# 22          70       2                      saab 99e
# ...

# %%
mcmean = mcgroup.mean(numeric_only=True)
mcmean
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 71         4          27.461538    101.846154  2056.384615     16.961538
#            6          18.000000    243.375000  3171.875000     14.750000
#            8          13.428571    371.714286  4537.714286     12.214286
# 72         3          19.000000     70.000000  2330.000000     13.500000
#            4          23.428571    111.535714  2382.642857     17.214286
#            8          13.615385    344.846154  4228.384615     13.000000
# 73         3          18.000000     70.000000  2124.000000     13.500000
#            4          22.727273    109.272727  2338.090909     17.136364
# ...

# %%
mcmean.index
# Out:
# MultiIndex([(70, 4),
#             (70, 6),
#             (70, 8),
#             (71, 4),
#             (71, 6),
#             (71, 8),
#             (72, 3),
#             (72, 4),
#             (72, 8),
#             (73, 3),
#             (73, 4),
#             (73, 6),
#             (73, 8),
#             (74, 4),
#             (74, 6),
#             (74, 8),
#             (75, 4),
#             (75, 6),
#             (75, 8),
#             (76, 4),
#             (76, 6),
#             (76, 8),
#             (77, 3),
#             (77, 4),
#             (77, 6),
#             (77, 8),
#             (78, 4),
#             (78, 5),
#             (78, 6),
#             (78, 8),
#             (79, 4),
#             (79, 5),
#             (79, 6),
#             (79, 8),
#             (80, 3),
#             (80, 4),
#             (80, 5),
#             (80, 6),
#             (81, 4),
#             (81, 6),
#             (81, 8),
#             (82, 4),
#             (82, 6)],
# ...

# %%
mcmean.head()
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 71         4          27.461538    101.846154  2056.384615     16.961538
#            6          18.000000    243.375000  3171.875000     14.750000
#
#                         origin
# model_year cylinders
# 70         4          2.285714
#            6          1.000000
#            8          1.000000
# 71         4          1.923077
#            6          1.000000

# %%
mcmean.loc[70]
# Out:
#                  mpg  displacement       weight  acceleration    origin
# cylinders
# 4          25.285714    107.000000  2292.571429     16.000000  2.285714
# 6          20.500000    199.000000  2710.500000     15.500000  1.000000
# 8          14.111111    367.555556  3940.055556     11.194444  1.000000

# %%
mcmean.loc[[70,72]]
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 72         3          19.000000     70.000000  2330.000000     13.500000
#            4          23.428571    111.535714  2382.642857     17.214286
#            8          13.615385    344.846154  4228.384615     13.000000
#
#                         origin
# model_year cylinders
# 70         4          2.285714
#            6          1.000000
#            8          1.000000
# 72         3          3.000000
#            4          1.928571
#            8          1.000000

# %%
mcmean.loc[(70,6)]
# Out:
# mpg               20.5
# displacement     199.0
# weight          2710.5
# acceleration      15.5
# origin             1.0
# Name: (70, 6), dtype: float64

# %% [markdown]
# ### 用來根據索引（index）選取特定的行或列。
# #### key=70：選取索引值為 70 的資料。
# #### axis=0：從 行索引（row index） 選取資料。
# #### level="model_year"：如果 g 是一個 MultiIndex DataFrame，則 70 是 model_year 這個層級的索引值。

# %%
mcmean.xs(key=70,axis=0,level="model_year")
# Out:
#                  mpg  displacement       weight  acceleration    origin
# cylinders
# 4          25.285714    107.000000  2292.571429     16.000000  2.285714
# 6          20.500000    199.000000  2710.500000     15.500000  1.000000
# 8          14.111111    367.555556  3940.055556     11.194444  1.000000

# %%
mcmean.xs(key=4,level="cylinders",axis=0)
# Out:
#                   mpg  displacement       weight  acceleration    origin
# model_year
# 70          25.285714    107.000000  2292.571429     16.000000  2.285714
# 71          27.461538    101.846154  2056.384615     16.961538  1.923077
# 72          23.428571    111.535714  2382.642857     17.214286  1.928571
# 73          22.727273    109.272727  2338.090909     17.136364  2.000000
# 74          27.800000     96.533333  2151.466667     16.400000  2.200000
# 75          25.250000    114.833333  2489.250000     15.833333  2.166667
# 76          26.766667    106.333333  2306.600000     16.866667  1.866667
# 77          29.107143    106.500000  2205.071429     16.064286  1.857143
# 78          29.576471    112.117647  2296.764706     16.282353  2.117647
# 79          31.525000    113.583333  2357.583333     15.991667  1.583333
# 80          34.612000    111.000000  2360.080000     17.144000  2.200000
# 81          32.814286    108.857143  2275.476190     16.466667  2.095238
# ...

# %%
import numpy as np
import pandas as pd

data_one = {'A': ['A0', 'A1', 'A2', 'A3'],'B': ['B0', 'B1', 'B2', 'B3']}
data_two = {'C': ['C0', 'C1', 'C2', 'C3'], 'D': ['D0', 'D1', 'D2', 'D3']}
one = pd.DataFrame(data_one)
two = pd.DataFrame(data_two)

# %%
one
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %%
two
# Out:
#     C   D
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %%
axis0 = pd.concat([one,two],axis=0)
axis0
# Out:
#      A    B    C    D
# 0   A0   B0  NaN  NaN
# 1   A1   B1  NaN  NaN
# 2   A2   B2  NaN  NaN
# 3   A3   B3  NaN  NaN
# 0  NaN  NaN   C0   D0
# 1  NaN  NaN   C1   D1
# 2  NaN  NaN   C2   D2
# 3  NaN  NaN   C3   D3

# %%
axis1 = pd.concat([one,two],axis=1)
axis1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
registrations = pd.DataFrame({'reg_id':[1,2,3,4],'name':['Andrew','Bobo','Claire','David']})
logins = pd.DataFrame({'log_id':[1,2,3,4],'name':['Xavier','Andrew','Yolanda','Bobo']})

# %%
registrations
# Out:
#    reg_id    name
# 0       1  Andrew
# 1       2    Bobo
# 2       3  Claire
# 3       4   David

# %%
logins
# Out:
#    log_id     name
# 0       1   Xavier
# 1       2   Andrew
# 2       3  Yolanda
# 3       4     Bobo

# %% [markdown]
# ## Inner,Left, Right, and Outer Joins

# %%
pd.merge(registrations,logins,how="inner",on="name")
# Out:
#    reg_id    name  log_id
# 0       1  Andrew       2
# 1       2    Bobo       4

# %%
pd.merge(registrations,logins,on="name")
# Out:
#    reg_id    name  log_id
# 0       1  Andrew       2
# 1       2    Bobo       4

# %%
pd.merge(registrations,logins,how="left",on="name")
# Out:
#    reg_id    name  log_id
# 0       1  Andrew     2.0
# 1       2    Bobo     4.0
# 2       3  Claire     NaN
# 3       4   David     NaN

# %%
pd.merge(registrations,logins,how="right",on="name")
# Out:
#    reg_id     name  log_id
# 0     NaN   Xavier       1
# 1     1.0   Andrew       2
# 2     NaN  Yolanda       3
# 3     2.0     Bobo       4

# %%
pd.merge(registrations,logins,how="outer",on="name")
# Out:
#    reg_id     name  log_id
# 0     1.0   Andrew     2.0
# 1     2.0     Bobo     4.0
# 2     3.0   Claire     NaN
# 3     4.0    David     NaN
# 4     NaN   Xavier     1.0
# 5     NaN  Yolanda     3.0

# %% [markdown]
# ## Pivot Tables(樞紐分析表)
# 樞紐分析數據有時能幫助澄清關係和連接。
#
# 有關各種相關樞紐方法的完整文檔： https://pandas.pydata.org/docs/user_guide/reshaping.html

# %%
import pandas as pd
import numba as np

df = pd.read_csv("Sales_Funnel_CRM.csv")
df
# Out:
#     Account Number       Company       Contact Account Manager  \
# 0          2123398        Google   Larry Pager    Edward Thorp
# 1          2123398        Google   Larry Pager    Edward Thorp
# 2          2123398        Google   Larry Pager    Edward Thorp
# 3          2192650          BOBO   Larry Pager    Edward Thorp
# 4           420496          IKEA     Elon Tusk    Edward Thorp
# 5           636685    Tesla Inc.     Elon Tusk    Edward Thorp
# 6           636685    Tesla Inc.     Elon Tusk    Edward Thorp
# 7          1216870     Microsoft   Will Grates    Edward Thorp
# 8          2200450       Walmart   Will Grates    Edward Thorp
# 9           405886         Apple  Cindy Phoner  Claude Shannon
# 10          470248  Exxon Mobile  Cindy Phoner  Claude Shannon
# 11          698032           ATT  Cindy Phoner  Claude Shannon
# 12          698032           ATT  Cindy Phoner  Claude Shannon
# 13          902797    CVS Health  Emma Gordian  Claude Shannon
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
license = df[["Company", "Product", "Licenses"]]
license
# Out:
#          Company          Product  Licenses
# 0         Google        Analytics       150
# 1         Google       Prediction       150
# 2         Google         Tracking       300
# 3           BOBO        Analytics       150
# 4           IKEA        Analytics       300
# 5     Tesla Inc.        Analytics       300
# 6     Tesla Inc.       Prediction       150
# 7      Microsoft         Tracking       300
# 8        Walmart        Analytics       150
# 9          Apple        Analytics       300
# 10  Exxon Mobile        Analytics       150
# 11           ATT         Tracking       150
# 12           ATT       Prediction       150
# 13    CVS Health         Tracking       450
# 14    Salesforce        Analytics       750
# 15         Cisco        Analytics       300
# 16         Cisco  GPS Positioning       300

# %%
pd.pivot(data=license,index="Company",columns="Product",values="Licenses")
# Out:
# Product       Analytics  GPS Positioning  Prediction  Tracking
# Company
#  Google           150.0              NaN       150.0     300.0
# ATT                 NaN              NaN       150.0     150.0
# Apple             300.0              NaN         NaN       NaN
# BOBO              150.0              NaN         NaN       NaN
# CVS Health          NaN              NaN         NaN     450.0
# Cisco             300.0            300.0         NaN       NaN
# Exxon Mobile      150.0              NaN         NaN       NaN
# IKEA              300.0              NaN         NaN       NaN
# Microsoft           NaN              NaN         NaN     300.0
# Salesforce        750.0              NaN         NaN       NaN
# Tesla Inc.        300.0              NaN       150.0       NaN
# Walmart           150.0              NaN         NaN       NaN

# %%
df
# Out:
#     Account Number       Company       Contact Account Manager  \
# 0          2123398        Google   Larry Pager    Edward Thorp
# 1          2123398        Google   Larry Pager    Edward Thorp
# 2          2123398        Google   Larry Pager    Edward Thorp
# 3          2192650          BOBO   Larry Pager    Edward Thorp
# 4           420496          IKEA     Elon Tusk    Edward Thorp
# 5           636685    Tesla Inc.     Elon Tusk    Edward Thorp
# 6           636685    Tesla Inc.     Elon Tusk    Edward Thorp
# 7          1216870     Microsoft   Will Grates    Edward Thorp
# 8          2200450       Walmart   Will Grates    Edward Thorp
# 9           405886         Apple  Cindy Phoner  Claude Shannon
# 10          470248  Exxon Mobile  Cindy Phoner  Claude Shannon
# 11          698032           ATT  Cindy Phoner  Claude Shannon
# 12          698032           ATT  Cindy Phoner  Claude Shannon
# 13          902797    CVS Health  Emma Gordian  Claude Shannon
# ...

# %%
myData = pd.pivot_table(df,index="Company",aggfunc="sum")
print(type(myData))
myData
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                    Account Manager  Account Number  \
# Company
#  Google       Edward ThorpEdward ThorpEdward Thorp         6370194
# ATT                   Claude ShannonClaude Shannon         1396064
# Apple                               Claude Shannon          405886
# BOBO                                  Edward Thorp         2192650
# CVS Health                          Claude Shannon          902797
# Cisco                 Claude ShannonClaude Shannon         4338998
# Exxon Mobile                        Claude Shannon          470248
# IKEA                                  Edward Thorp          420496
# Microsoft                             Edward Thorp         1216870
# Salesforce                          Claude Shannon         2046943
# Tesla Inc.                Edward ThorpEdward Thorp         1273370
# Walmart                               Edward Thorp         2200450
#
# ...

# %%
myData[["Licenses","Sale Price"]]
# Out:
#               Licenses  Sale Price
# Company
#  Google            600     3150000
# ATT                300     1050000
# Apple              300     4550000
# BOBO               150     2450000
# CVS Health         450      490000
# Cisco              600     4900000
# Exxon Mobile       150     2100000
# IKEA               300     4550000
# Microsoft          300      350000
# Salesforce         750     7000000
# Tesla Inc.         450     3500000
# Walmart            150     2450000

# %%
pd.pivot_table(df,index="Company",aggfunc="sum",values=["Licenses","Sale Price"])
# Out:
#               Licenses  Sale Price
# Company
#  Google            600     3150000
# ATT                300     1050000
# Apple              300     4550000
# BOBO               150     2450000
# CVS Health         450      490000
# Cisco              600     4900000
# Exxon Mobile       150     2100000
# IKEA               300     4550000
# Microsoft          300      350000
# Salesforce         750     7000000
# Tesla Inc.         450     3500000
# Walmart            150     2450000

# %%
pd.pivot_table(df,index=["Account Manager","Contact"],values=["Sale Price","Licenses"],aggfunc="sum")
# Out:
#                               Licenses  Sale Price
# Account Manager Contact
# Claude Shannon  Cindy Phoner       750     7700000
#                 Emma Gordian      1800    12390000
# Edward Thorp    Elon Tusk          750     8050000
#                 Larry Pager        750     5600000
#                 Will Grates        450     2800000

# %%
pd.pivot_table(df,index=["Account Manager","Contact"],values=["Sale Price","Licenses"],columns=["Product"],aggfunc="sum")
# Out:
#                               Licenses                                      \
# Product                      Analytics GPS Positioning Prediction Tracking
# Account Manager Contact
# Claude Shannon  Cindy Phoner     450.0             NaN      150.0    150.0
#                 Emma Gordian    1050.0           300.0        NaN    450.0
# Edward Thorp    Elon Tusk        600.0             NaN      150.0      NaN
#                 Larry Pager      300.0             NaN      150.0    300.0
#                 Will Grates      150.0             NaN        NaN    300.0
#
#                               Sale Price
# Product                        Analytics GPS Positioning Prediction  Tracking
# Account Manager Contact
# Claude Shannon  Cindy Phoner   6650000.0             NaN   700000.0  350000.0
#                 Emma Gordian  11550000.0        350000.0        NaN  490000.0
# Edward Thorp    Elon Tusk      7350000.0             NaN   700000.0       NaN
# ...

# %%
pd.pivot_table(df,index=["Account Manager","Contact"],values=["Sale Price","Licenses"],columns=["Product"],aggfunc=["sum","mean","std"],fill_value=0)
# Out:
#                                    sum                                      \
#                               Licenses
# Product                      Analytics GPS Positioning Prediction Tracking
# Account Manager Contact
# Claude Shannon  Cindy Phoner       450               0        150      150
#                 Emma Gordian      1050             300          0      450
# Edward Thorp    Elon Tusk          600               0        150        0
#                 Larry Pager        300               0        150      300
#                 Will Grates        150               0          0      300
#
#                                                                              \
#                              Sale Price
# Product                       Analytics GPS Positioning Prediction Tracking
# Account Manager Contact
# Claude Shannon  Cindy Phoner    6650000               0     700000   350000
#                 Emma Gordian   11550000          350000          0   490000
# ...

# %%
import pandas as pd

hotels = pd.read_csv("hotel_booking_data.csv")
hotels.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
hotels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
len(hotels)
# Out:
# 119390

# %% [markdown]
# ## 有多少遺失值

# %%
hotels.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# ## 移除company欄位

# %%
try:
    hotels.drop("company",axis=1,inplace=True)
except:
    pass
hotels.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             488
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %% [markdown]
# ## country 在資料中數量最多的前五筆

# %%
hotels["country"].value_counts()[:5]
# Out:
# country
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
# Name: count, dtype: int64

# %% [markdown]
# ## 請問支付最高平均每日房價（ADR）的人的名字是什麼？他們的ADR是多少？

# %%
hotels_sort = hotels.sort_values(["adr","name"],ascending=[False,False])
hotels_sort.head()
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 48515     City Hotel            1         35               2016
# 111403    City Hotel            0          0               2017
# 15083   Resort Hotel            0          1               2015
# 103912    City Hotel            0         81               2016
# 13142   Resort Hotel            1        378               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 48515               March                        13
# 111403                May                        19
# 15083                July                        29
# 103912           December                        53
# 13142              August                        31
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 48515                          25                        0
# 111403                          9                        0
# 15083                          15                        0
# ...

# %%
hotels_sort[['name','adr']].head()
# Out:
#                   name     adr
# 48515    Daniel Walter  5400.0
# 111403     Jesus Mason   510.0
# 15083   Samuel Hammond   508.0
# 103912  Jessica Morris   451.5
# 13142        Amy Banks   450.0
